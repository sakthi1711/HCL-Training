# %%
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO


model = YOLO("yolov5n.pt")  # small and fast model

img_path = "auto.jpg"
img = cv2.imread(img_path)
results = model(img)

for r in results:
    annotated = r.plot()  #bounding boxes
    plt.imshow(cv2.cvtColor(annotated, cv2.COLOR_BGR2RGB))
    plt.axis("off")
    plt.show()

# detected classes and confidences
for box in results[0].boxes:
    cls = int(box.cls[0])
    conf = float(box.conf[0])
    print(f"Detected: {model.names[cls]} (Confidence: {conf:.2f})")
# Out:
# PRO TIP 💡 Replace 'model=yolov5n.pt' with new 'model=yolov5nu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov5nu.pt to 'yolov5nu.pt': 100% ━━━━━━━━━━━━ 5.3MB 71.7MB/s 0.1s
# WARNING ⚠️ 'source' is missing. Using 'source=/usr/local/lib/python3.12/dist-packages/ultralytics/assets'.
#
# image 1/2 /usr/local/lib/python3.12/dist-packages/ultralytics/assets/bus.jpg: 640x480 4 persons, 1 bus, 24.3ms
# image 2/2 /usr/local/lib/python3.12/dist-packages/ultralytics/assets/zidane.jpg: 384x640 3 persons, 2 ties, 15.2ms
# Speed: 2.3ms preprocess, 19.8ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
# Detected: person (Confidence: 0.83)
# Detected: bus (Confidence: 0.80)
# Detected: person (Confidence: 0.80)
# Detected: person (Confidence: 0.76)
# Detected: person (Confidence: 0.30)
